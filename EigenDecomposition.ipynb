# %%
import numpy as np 
from numpy import linalg

# %%
A = np.arange(9) -3 #Se le agrega el inicio en array y arange 
B = np.array(range(9)) -3
print (A)
print (B)
# Out:
# [-3 -2 -1  0  1  2  3  4  5]
# [-3 -2 -1  0  1  2  3  4  5]

# %%
print("La dimension de la matriz A es:", format(A.shape))
print("El tamaño de la matriz A es:", format(A.size))
print("La dimension de la matriz B es:", format(B.shape))
print("El tamaño de la matriz B es:", format(B.size))
# Out:
# La dimension de la matriz A es: (9,)
# El tamaño de la matriz A es: 9
# La dimension de la matriz B es: (9,)
# El tamaño de la matriz B es: 9

# %%
A = A.reshape((3,3))
print (A)
print (B)
# Out:
# [[-3 -2 -1]
#  [ 0  1  2]
#  [ 3  4  5]]
# [-3 -2 -1  0  1  2  3  4  5]

# %%
#Norma euclidiana

# %%
print(np.linalg.norm(A))
print(np.linalg.norm(B))
# Out:
# 8.306623862918075
# 8.306623862918075

# %%
print(np.linalg.norm(A,'fro'))
#print(np.linalg.norm(B,'fro')) #No hay norma si es vectorenglon
# Out:
# 8.306623862918075

# %%
#Norma maxima (P=infinito)
print (np.linalg.norm(A,np.inf))
print (np.linalg.norm(B,np.inf))#vector renglon, el mayor es el 5
# Out:
# 12.0
# 5.0

# %%
#NOrmalizacion 
ANorm = np.linalg.norm(A) 
BNorm = np.linalg.norm(B)
print("La norma de A es :",ANorm)
print("La norma de B es :",BNorm)
A_unit = A/ANorm
B_unit = B/BNorm 
print ("")
print("el vector Normal de A es :")
print(A_unit)
print ("")
print("el vector Normal de B es :")
print(B_unit)
# Out:
# La norma de A es : 8.306623862918075
# La norma de B es : 8.306623862918075
#
# el vector Normal de A es :
# [[-0.36115756 -0.24077171 -0.12038585]
#  [ 0.          0.12038585  0.24077171]
#  [ 0.36115756  0.48154341  0.60192927]]
#
# el vector Normal de B es :
# [-0.36115756 -0.24077171 -0.12038585  0.          0.12038585  0.24077171
#   0.36115756  0.48154341  0.60192927]

# %%
#Comprobacion 
print("la norma de A es:",np.linalg.norm(A_unit))
print("la norma de B es:",np.linalg.norm(B_unit))
# Out:
# la norma de A es: 0.9999999999999999
# la norma de B es: 0.9999999999999999

# %% [markdown]
# ### Eigendecomposition
# $$\textbf{Av}=\lambda\textbf{v}$$

# %%
I = np.zeros((3,3),dtype=int)
I[0,0]=1 
I[1,1]=1  
I[2,2]=1
print ("I=","\n",I,"\n")
B = np.diag((1,2,3))
print("B=","\n",B,"\n")
C = np.diag(np.arange(1,4))
print("C=","\n",C)
# Out:
# I=
#  [[1 0 0]
#  [0 1 0]
#  [0 0 1]]
#
# B=
#  [[1 0 0]
#  [0 2 0]
#  [0 0 3]]
#
# C=
#  [[1 0 0]
#  [0 2 0]
#  [0 0 3]]

# %%
#Sean los Eigenvalores y Eigenvectores, EVal y Evec respectivamente

# %%
EVal,EVec=np.linalg.eig(B)
print("Eigenvalores de B:",EVal)
print("Eigenvector de B:","\n",EVec)
#Los eigenvectores se almacenan en matriz como vectores columna
# Out:
# Eigenvalores de B: [1. 2. 3.]
# Eigenvector de B:
#  [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
EValC,EVecC=np.linalg.eig(C)
print("Eigenvalores de C:",EValC)
print("Eigenvector de C:","\n",EVecC)
#Los eigenvectores se almacenan en matriz como vectores columna
# Out:
# Eigenvalores de C: [1. 2. 3.]
# Eigenvector de C:
#  [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
EValC
# Out:
# array([1., 2., 3.])

# %%
EVecC
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
print('Eigenvalues : {}'.format(EValC[1]))#Eigenvalor
print('Eigenvector : {}'.format(EVecC[0]))#Vector columna
# Out:
# Eigenvalues : 2.0
# Eigenvector : [1. 0. 0.]

# %% [markdown]
# $$\textbf{A}=\textbf{V}diag(\lambda)\textbf{V}^{-1}$$
# Sea $\lambda$ los eigenvalores, y sea $\textbf{V}$ una matriz con un eigenvector por columna

# %%
np.diag(EValC) #crear matriz diagonal con valores especificos
# Out:
# array([[1., 0., 0.],
#        [0., 2., 0.],
#        [0., 0., 3.]])

# %%
np.linalg.inv(EVecC) #obtener matriz inversa
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
CMatrix = np.matmul(np.diag(EValC),np.linalg.inv(EVecC))
output = np.matmul(EVecC,CMatrix).astype(np.int)
print(output)
# Out:
# [[1 0 0]
#  [0 2 0]
#  [0 0 3]]

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
origin = [0,0,0]
fig = plt.figure(figsize=(18,10))
ax1=fig.add_subplot(121,projection = '3d')

ax1.quiver(origin,origin,origin,EVecC[0,:],EVecC[1,:],EVecC[2,:],color='k')
ax1.set_xlim([-3,3])
ax1.set_ylim([-3,3])
ax1.set_zlim([-3,3])
ax1.set_xlabel('X Axis')
ax1.set_ylabel('Y Axis')
ax1.set_zlabel('Z Axis')
ax1.view_init(15,30)
ax1.set_title('Premultiplicacion')
#
nvo_eig=np.matmul(C,EVecC)
ax2=fig.add_subplot(122,projection = '3d')

ax2.quiver(origin,origin,origin,nvo_eig[0,:],nvo_eig[1,:],nvo_eig[2,:],color='k')

ax2.plot((EValC[0]*EVecC[0]),(EValC[1]*EVecC[1]),(EValC[2]*EVecC[2]),'rX')

ax2.set_xlim([-3,3])
ax2.set_ylim([-3,3])
ax2.set_zlim([-3,3])
ax2.set_xlabel('X Axis')
ax2.set_ylabel('Y Axis')
ax2.set_zlabel('Z Axis')
ax2.view_init(15,30)
ax2.set_title('Postmultiplicacion')

plt.show()
