# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,3*np.pi)
y=np.cos(x)
y1=np.sin(x)
y2=np.tan(x)
y3=np.exp(x)
y4=5*x**.5

# %%
fig=plt.subplots(3,3,figsize=(10,6))

# %%
fig=plt.figure(figsize=(10,6))
ax1=fig.add_subplot(311)
plt.plot(x,y)
#plt.xticks(rotation=45)

ax2=fig.add_subplot(323)
plt.plot(x,y3)
#plt.yticks(rotation=45)

ax3=fig.add_subplot(324)
plt.plot(x,y2)
plt.
#plt.yticks(rotation=45)

plt.tight_layout()

# %%
fig=plt.figure()
ax1=plt.subplot2grid((6,2),(0,0),rowspan=2,colspan=2)
plt.plot(x,y)
ax2=plt.subplot2grid((6,1),(2,0),rowspan=2,colspan=1)
plt.plot(x,y4)

# %%
pi=np.pi
plt.style.use("ggplot")
plt.plot(x,y,label="Sin(x)")
plt.plot(np.pi,-1,"o")
plt.plot(x,y1)
plt.legend()

plt.axhline(0,color="k")
plt.axvline(np.pi,color="k")
plt.axvline(2*np.pi,color="k")
